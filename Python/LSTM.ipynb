# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import io
from tqdm import trange

# %%
##########################################################################
################## Sigmoid function ######################################

def calcSig(inputs, outputs, wGate, wHidden, bias):
    gate = tf.sigmoid(tf.matmul(inputs,wGate) + tf.matmul(outputs,wHidden) + bias)
    return gate
    
##########################################################################

################## LSTM-block function ###################################

def block(inputs, outputs, cell_state, array_of_weights, array_of_bias): 
    inputG = calcSig(inputs, outputs, array_of_weights[0], array_of_weights[1], array_of_bias[0])
    forgetG = calcSig(inputs, outputs, array_of_weights[2], array_of_weights[3], array_of_bias[1])
    outputG = calcSig(inputs, outputs, array_of_weights[4], array_of_weights[5], array_of_bias[2])
    memoryG = calcSig(inputs, outputs, array_of_weights[6], array_of_weights[7], array_of_bias[3])

    cell_state = cell_state * forgetG + inputG * memoryG    # final cell state C
    output_f = tf.tanh(cell_state) * outputG                # final output h

    return cell_state, output_f
    
##########################################################################

class LSTM():
    def __init__(self, batch_size, window_size, hidden_layers, clip_margin, learning_rate, epochs):
        self.batch_size = batch_size
        self.window_size = window_size
        self.hidden_layers = hidden_layers
        self.clip_margin = clip_margin
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.trained_data = []#np.array([]) #np.array([[0 for ii in range(self.batch_size)]for i in range(self.epochs)])
        self.epoch_error = []#np.array([]) 
        ##
        
       
        generated_values1 = tf.truncated_normal([1,hidden_layers],stddev = 0.05)
        generated_values2 = tf.truncated_normal([hidden_layers,hidden_layers], stddev = 0.05)
        bias_values = tf.zeros([hidden_layers])

        # Weights
        W_inputG = tf.Variable(generated_values1)       #  weights input gate
        W_inputH = tf.Variable(generated_values2)       #  weights input hidden layer
        W_forgetG = tf.Variable(generated_values1)
        W_forgetH = tf.Variable(generated_values2)
        W_outputG = tf.Variable(generated_values1)
        W_outputH = tf.Variable(generated_values2)
        W_memoryG = tf.Variable(generated_values1)
        W_memoryH = tf.Variable(generated_values2)
        W_Output = tf.Variable(tf.truncated_normal([hidden_layers,1],stddev = 0.05))

        self.array_of_weights = np.array([W_inputG, W_inputH, W_forgetG,W_forgetH,W_outputG,W_outputH, W_memoryG, W_memoryH,W_Output])
       
        
        # Bias
        B_input = tf.Variable(bias_values)
        B_forget = tf.Variable(bias_values)
        B_output = tf.Variable(bias_values)
        B_memory = tf.Variable(bias_values)
        B_Output = tf.Variable(tf.zeros(1))

        self.array_of_bias = np.array([B_input, B_forget, B_output, B_memory, B_Output])

        # Placeholders
        inputs = tf.placeholder(tf.float32,[batch_size,window_size, 1])
        targets = tf.placeholder(tf.float32, [batch_size, 1])

##########################################################################
################## Windowing function ####################################

    def windowed_data(self, data, window_size):
        X = []
        y = []
        i = 0

        while (i + window_size) <= len(data) - 1:
            X.append(data[i:i+window_size])
            
            y.append(data[i+window_size])

            i += 1
        assert len(y) == len(X)
        return X, y
    


################## Loop ######################################
    def loop(self,inputs):
        outputs_h =[]
        for ii in range(batch_size):
            batch_state = np.zeros([1, hidden_layers], dtype=np.float32)
            batch_output = np.zeros([1, hidden_layers], dtype=np.float32)

            for jj in range(window_size): 
                batch_state, batch_output = block(tf.reshape(inputs[ii][jj], (-1,1)), batch_state, batch_output,self.array_of_weights,self.array_of_bias)
                
            outputs_h.append(tf.matmul(batch_output,self.array_of_weights[8]) + self.array_of_bias[4])

        return outputs_h

##################################################################################
###### Looking at the performance by defining the loss by mean squared error #####
    def mseErrors(self,targets,outputs_h):
        errors = []
        a = []

        for ii in range(len(outputs_h)):
            aux_reshape = tf.reshape(targets[ii],(-1,1))
            a = errors.append(tf.losses.mean_squared_error(aux_reshape, outputs_h[ii]))
        error = tf.reduce_mean(errors)
        
        return error
##########################################################################

############################# Training ###################################
    def training(self,X_train, y_train, outputs_h, error):
        print("Calculating the 'optimizer'...")
        optimizer = tf.train.GradientDescentOptimizer(self.learning_rate)
        print("Calculating the 'op'...")
        op = optimizer.minimize(error)
        session = tf.Session()
        session.run(tf.global_variables_initializer())
        print("Going into the loop")
        for ii in range(epochs):
            print("In for-loop:", ii)
            epoch_error = []
            jj = 0
            count = 0
            print("Calculating the 'a,b' from Session.run...")
            while(jj + batch_size) <= len(X_train)/2: # take away /2
                X_batch = X_train[jj:jj + batch_size]
                y_batch = y_train[jj:jj + batch_size]
                
                a, b, _ = session.run([outputs_h, error, op],feed_dict = {inputs:X_batch, targets:y_batch})
                print("size_of_a:", len(a))
                aux_a = np.array([a])
                print("size_of_a:", aux_a.shape)
                
                # ERROR HERE 
                #self.trained_data = np.extend(aux_a)#self.trained_data.append(a) #np.concatenate((self.trained_data,a), axis=ii) # 
                self.trained_data.append(a)#(aux_a)
                self.epoch_error.append(b) #np.concatenate((self.epoch_error,b), axis=ii)#
                
                jj += batch_size
                count += 1
                print("count, in while-loop:", count)
            
            if (ii % 30) == 0:
                print('Epoch {}/{}'.format(ii,self.epochs),'Current loss {}'.format(np.mean(epoch_error)))

# %% [markdown]
# Here is the code for loading of data

# %%
####### The first data import try, works sort of ######### 
nInputs = 21
nOutputs = 7
split = 0.5
data = np.genfromtxt('Sarcos_csv.csv', delimiter=',')
ind = round(split*data.shape[0])

X_train = data[0:ind,0:nInputs,np.newaxis]
y_train = data[0:ind,1:2] #y_train = data[0:ind,nInputs:,np.newaxis]
X_test = data[ind:,0:nInputs,np.newaxis]
y_test = data[ind:,nInputs:,np.newaxis]


#### Jacobs method
############ Loading data ############## 
# load csv data for input and output

# 7 columns each for joint angles, angular velocities and angular acceleraions
#uVec = pd.read_csv("Sarcos_csv.csv", usecols=np.arange(21),  header=None,
#                  names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 
#                           'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7'])
# 7 columns for joint torques
#yVec = pd.read_csv("Sarcos_csv.csv", usecols=np.arange(21, 28, 1), header=None, 
#                  names = ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7'])

# to numpy array
#u = uVec.values[:, :, np.newaxis]
#y = yVec.values[:, :]#, np.newaxis]
#print("shape_y:",y.shape)
#split = 0.5
#ind = round(split*u.shape[0])
#print("ind:",ind)
#X_train = u[0:ind,0:nInputs]#,:]
#y_train = y[0:ind,0:]#,np.newaxis]#1:2] 
#X_test = u[ind:,0:nInputs]#,:]
#y_test = y[ind:,0:]#,np.newaxis]

print("X_train size: {}".format(X_train.shape))
print("y_train size: {}".format(y_train.shape))
print("X_test size: {}".format(X_test.shape))
print("y_test size: {}".format(X_test.shape))
# Out:
# X_train size: (22242, 21, 1)
# y_train size: (22242, 1)
# X_test size: (22242, 21, 1)
# y_test size: (22242, 21, 1)

# %%
############################################################################
# Defining hyperparameters, THEY SHOULD BE MODIFIED
batch_size = 20  # number of windows passed at once
window_size = 10  # number of data points we want to predict
hidden_layers = 50  #250, number of hidden layers in the LSTM
clip_margin = 4  # used to clip gradients above/below its margins
learning_rate = 0.0001  # way to optimize the loss function
epochs = 1 #200  # number of iterations the model needs to make (forward and back propagation)

############################################################################
############################################################################
callingClass = LSTM(batch_size,window_size,hidden_layers,clip_margin,learning_rate,epochs)

# Splitting into training and validation data
#X, y = callingClass.windowed_data(scaled_data,window_size)
#size_of_80p = int(len(scaled_data) * 0.8)

#X_train = np.array(X[:size_of_80p])  # we want 80 % to be training data
#y_train = np.array(y[:size_of_80p])

#X_test = np.array(X[size_of_80p:])
#y_test = np.array(y[size_of_80p:])

#print("X_train size: {}".format(X_train.shape))
#print("y_train size: {}".format(y_train.shape))
#print("X_test size: {}".format(X_test.shape))
#print("y_test size: {}".format(X_test.shape))
############################################################################

# %%
###### Running the functions ########
# Placeholders
inputs = tf.placeholder(tf.float32,[batch_size,nInputs, 1]) #[batch_size,window_size, 1]
targets = tf.placeholder(tf.float32,[batch_size, 1]) # change it to: [batch_size, nOutputs]?

#weights = callingClass.array_of_weights
#bias = callingClass.array_of_bias
#batch_state = np.zeros([1, hidden_layers], dtype=np.float32)
#batch_output = np.zeros([1, hidden_layers], dtype=np.float32)

###### Looping to create the outputs h(t) ####### 
print("Calculating the 'outputs_h'...")
outputs_h = callingClass.loop(inputs)

############################################################################
####### Checking mean-squared error ##########
print("Calculating the 'MSE'...")
MSE = callingClass.mseErrors(targets,outputs_h)

############################################################################
################## Learning ###################

print("Calculating the 'LEARNING'...")
callingClass.training(X_train,y_train,outputs_h,MSE)
print("DONE")
# Out:
# Calculating the 'outputs_h'...
# Calculating the 'MSE'...
# Calculating the 'LEARNING'...
# Calculating the 'optimizer'...
# Calculating the 'op'...
# Going into the loop
# In for-loop: 0
# Calculating the 'a,b' from Session.run...
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 1
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 2
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 3
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 4
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 5
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 6
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 7
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 8
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 9
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 10
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 11
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 12
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 13
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 14
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 15
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 16
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 17
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 18
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 19
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 20
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 21
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 22
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 23
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 24
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 25
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 26
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 27
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 28
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 29
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 30
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 31
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 32
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 33
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 34
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 35
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 36
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 37
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 38
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 39
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 40
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 41
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 42
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 43
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 44
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 45
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 46
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 47
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 48
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 49
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 50
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 51
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 52
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 53
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 54
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 55
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 56
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 57
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 58
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 59
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 60
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 61
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 62
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 63
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 64
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 65
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 66
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 67
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 68
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 69
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 70
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 71
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 72
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 73
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 74
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 75
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 76
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 77
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 78
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 79
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 80
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 81
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 82
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 83
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 84
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 85
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 86
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 87
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 88
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 89
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 90
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 91
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 92
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 93
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 94
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 95
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 96
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 97
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 98
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 99
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 100
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 101
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 102
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 103
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 104
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 105
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 106
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 107
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 108
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 109
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 110
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 111
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 112
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 113
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 114
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 115
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 116
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 117
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 118
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 119
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 120
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 121
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 122
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 123
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 124
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 125
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 126
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 127
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 128
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 129
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 130
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 131
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 132
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 133
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 134
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 135
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 136
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 137
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 138
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 139
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 140
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 141
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 142
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 143
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 144
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 145
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 146
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 147
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 148
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 149
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 150
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 151
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 152
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 153
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 154
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 155
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 156
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 157
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 158
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 159
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 160
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 161
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 162
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 163
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 164
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 165
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 166
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 167
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 168
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 169
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 170
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 171
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 172
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 173
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 174
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 175
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 176
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 177
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 178
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 179
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 180
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 181
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 182
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 183
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 184
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 185
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 186
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 187
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 188
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 189
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 190
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 191
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 192
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 193
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 194
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 195
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 196
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 197
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 198
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 199
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 200
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 201
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 202
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 203
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 204
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 205
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 206
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 207
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 208
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 209
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 210
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 211
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 212
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 213
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 214
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 215
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 216
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 217
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 218
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 219
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 220
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 221
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 222
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 223
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 224
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 225
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 226
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 227
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 228
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 229
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 230
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 231
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 232
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 233
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 234
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 235
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 236
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 237
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 238
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 239
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 240
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 241
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 242
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 243
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 244
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 245
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 246
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 247
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 248
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 249
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 250
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 251
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 252
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 253
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 254
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 255
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 256
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 257
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 258
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 259
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 260
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 261
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 262
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 263
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 264
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 265
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 266
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 267
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 268
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 269
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 270
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 271
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 272
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 273
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 274
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 275
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 276
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 277
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 278
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 279
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 280
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 281
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 282
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 283
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 284
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 285
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 286
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 287
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 288
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 289
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 290
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 291
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 292
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 293
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 294
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 295
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 296
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 297
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 298
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 299
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 300
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 301
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 302
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 303
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 304
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 305
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 306
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 307
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 308
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 309
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 310
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 311
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 312
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 313
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 314
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 315
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 316
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 317
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 318
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 319
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 320
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 321
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 322
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 323
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 324
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 325
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 326
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 327
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 328
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 329
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 330
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 331
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 332
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 333
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 334
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 335
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 336
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 337
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 338
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 339
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 340
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 341
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 342
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 343
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 344
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 345
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 346
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 347
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 348
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 349
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 350
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 351
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 352
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 353
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 354
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 355
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 356
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 357
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 358
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 359
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 360
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 361
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 362
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 363
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 364
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 365
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 366
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 367
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 368
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 369
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 370
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 371
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 372
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 373
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 374
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 375
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 376
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 377
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 378
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 379
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 380
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 381
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 382
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 383
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 384
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 385
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 386
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 387
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 388
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 389
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 390
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 391
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 392
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 393
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 394
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 395
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 396
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 397
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 398
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 399
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 400
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 401
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 402
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 403
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 404
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 405
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 406
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 407
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 408
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 409
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 410
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 411
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 412
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 413
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 414
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 415
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 416
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 417
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 418
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 419
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 420
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 421
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 422
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 423
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 424
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 425
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 426
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 427
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 428
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 429
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 430
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 431
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 432
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 433
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 434
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 435
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 436
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 437
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 438
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 439
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 440
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 441
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 442
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 443
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 444
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 445
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 446
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 447
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 448
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 449
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 450
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 451
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 452
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 453
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 454
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 455
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 456
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 457
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 458
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 459
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 460
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 461
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 462
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 463
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 464
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 465
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 466
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 467
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 468
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 469
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 470
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 471
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 472
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 473
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 474
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 475
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 476
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 477
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 478
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 479
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 480
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 481
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 482
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 483
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 484
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 485
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 486
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 487
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 488
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 489
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 490
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 491
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 492
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 493
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 494
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 495
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 496
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 497
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 498
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 499
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 500
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 501
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 502
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 503
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 504
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 505
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 506
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 507
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 508
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 509
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 510
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 511
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 512
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 513
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 514
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 515
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 516
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 517
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 518
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 519
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 520
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 521
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 522
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 523
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 524
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 525
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 526
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 527
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 528
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 529
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 530
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 531
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 532
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 533
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 534
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 535
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 536
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 537
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 538
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 539
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 540
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 541
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 542
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 543
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 544
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 545
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 546
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 547
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 548
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 549
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 550
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 551
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 552
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 553
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 554
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 555
# size_of_a: 20
# size_of_a: (1, 20, 1, 1)
# count, in while-loop: 556
# Epoch 0/1 Current loss nan
# /anaconda3/envs/dml/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/envs/dml/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# DONE

# %%
epoch_imported = callingClass.epochs
batch_size_imported = callingClass.batch_size
size_of_X_train = len(X_train)
length_sample = round(epoch_imported*(size_of_X_train/2)/batch_size_imported)
print("epoch_imported:",epoch_imported )
print("batch_size_imported:", batch_size_imported)
print("size_of_Xtrain:", size_of_X_train)
print("length_sample:",length_sample)
print()

trained_data_imported = callingClass.trained_data
error_of_trained_data = callingClass.epoch_error
trained_data_what_type = type(trained_data_imported) #should change it to numpy array? 
sizeOf_trained_data_imported = len(trained_data_imported)
#shapeOf_trained_data_imported = trained_data_imported.shape
print("len_trained_data_imported:", len(trained_data_imported))
print("len_epoch_error:", len(error_of_trained_data))
print("trained_data_what_type:",trained_data_what_type)
print("sizeOf_trained_data_imported:", sizeOf_trained_data_imported)
#print("sizeOf_trained_data_imported:",sizeOf_trained_data_imported)


#print("trained_data_imported:",trained_data_imported)
# Out:
# epoch_imported: 1
# batch_size_imported: 20
# size_of_Xtrain: 22242
# length_sample: 556
#
# len_trained_data_imported: 556
# len_epoch_error: 556
# what_type: <class 'list'>
# sizeOf_trained_data_imported: 556

# %% [markdown]
# Questions:
#     * Are the dimensions on X_train and y_train correct? (I want y_train to be: [*lotsofdata*, 7], but then problem in code)
#     * I want to extract the result of the training and plot it (the trained data and the error)
#     * The type of the trained data is list, how do i operate on these lists? (trying to change to numpy)
#     * Should i pre-define the size of the output ttrained_data and epoch_error as the size of the input data? I want to "group" it for each joint for each attribute(pos,val,acc,torq), tried hstack but wont work
#     * Are the placeholders defined correctly?
#
# Should I try to load the data as Jacob did? Yes -> [*lotsofdata*, 7]

# %%
## Making the data plottable ## 

###########################################################################
################## Plotting the data ######################################
## Figure 1 
plt.figure(figsize=(16,7))
plt.title('Data')
plt.xlabel('Samples')
plt.ylabel('Torque')
#plt.plot(scaled_data,label='Original data')
plt.plot(trained_data_imported,length_sample,label = 'Training data')
#plt.plot(test_data, label = 'Testing data')
plt.legend()
plt.show()

## Figure 2 
#plt.figure(figsize=(16,7))
#plt.title('Error')

# %% [markdown]
# * Improve by reducing the window size
# * How to get the acutually data as inputs/target (placeholders)?

# %% [markdown]
# Crap-code:

# %%
############### This might be done in main as well ####################### 
#Loading data and converting it into a .csv file
#data_xls = pd.read_excel('Sarcos.xls', 'Sheet1', index_col=None).astype(np.float32)
#data_xls.to_csv('Sarcos_csv.csv', encoding='utf-8')
#data = pd.read_csv('Sarcos_csv.csv',encoding='utf-8')

####### HERE, LOOP OVER ALL COLUMNS IN THE CSV-FILE AND CONSTRUCT A MATRIX CONTAINING ALL DATA #######
#loaded_data = np.array([[0 for ii in range(data.shape[0])]for i in range(data.shape[1])])
#nr_col_data = data.shape[1]
#for ii in range(nr_col_data):
    
#    data1 = data.iloc[:, ii]  # reading from index 1 in the csv file
#    loaded_data = np.insert(loaded_data,(1,ii),data1)
    #scaler = StandardScaler()
    #scaled_data = scaler.fit_transform(data1.values.reshape(-1, 1))
    
#print("loaded_data:",loaded_data)  
#print("size_of_loaded_data:",loaded_data.shape)
